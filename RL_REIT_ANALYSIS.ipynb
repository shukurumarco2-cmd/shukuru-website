# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("IYR.csv")
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2010-01-04  46.450001  46.660000  45.529999  45.810001  26.637310  16952700
# 1  2010-01-05  45.810001  45.959999  45.290001  45.919998  26.701263  14523000
# 2  2010-01-06  45.939999  46.230000  45.709999  45.900002  26.689632  14859100
# 3  2010-01-07  45.869999  46.520000  45.369999  46.310001  26.928043  16364700
# 4  2010-01-08  46.189999  46.230000  45.590000  46.000000  26.747786  10629500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3774 entries, 0 to 3773
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3774 non-null   object
#  1   Open       3774 non-null   float64
#  2   High       3774 non-null   float64
#  3   Low        3774 non-null   float64
#  4   Close      3774 non-null   float64
#  5   Adj Close  3774 non-null   float64
#  6   Volume     3774 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 206.5+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3774.000000  3774.000000  3774.000000  3774.000000  3774.000000
# mean     77.675583    78.201163    77.094126    77.673103    61.330089
# std      14.575400    14.631293    14.500455    14.563426    19.191270
# min      42.340000    42.880001    41.709999    42.450001    24.683558
# 25%      67.485003    67.965000    67.022497    67.519997    44.807184
# 50%      78.320000    78.895000    77.790001    78.285000    61.019110
# 75%      86.615002    87.177500    85.927500    86.635000    77.273375
# max     116.500000   116.889999   115.879997   116.139999   103.561752
#
#              Volume
# count  3.774000e+03
# mean   8.489098e+06
# std    4.347091e+06
# min    9.817000e+05
# 25%    5.522075e+06
# 50%    7.405500e+06
# 75%    1.030545e+07
# max    4.094470e+07

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.hist(figsize=(12,8))
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("correlation matrix")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["Date"] = pd.to_datetime(df["Date"])
plt.figure(figsize=(14,6))
plt.plot(df["Date"], df["Close"])
plt.title("IYR Closing Price Over Time")
plt.xlabel("Dtae")
plt.ylabel("Closing Price")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df["Daily_Return"] = df["Close"].pct_change()
df[["Date","Close","Daily_Return"]].head()
# Out:
#         Date      Close  Daily_Return
# 0 2010-01-04  45.810001           NaN
# 1 2010-01-05  45.919998      0.002401
# 2 2010-01-06  45.900002     -0.000435
# 3 2010-01-07  46.310001      0.008932
# 4 2010-01-08  46.000000     -0.006694
